# %% [markdown]
# # Exercise 4.8

# %% [markdown]
# # Index
#
# 01 Importing Libraries
#
# 02 Importing Data
#
# 03 Grouping Data
#
# 04 Aggregating Data

# %% [markdown]
# # 01. Importing Libraries

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing Data

# %%
# create path
path = r'C:\Users\kthav\My Pc\Desktop\Career Foundry\Data Immersion\Python Fundamentals for Data Analytics\11-12-2024 Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\kthav\\My Pc\\Desktop\\Career Foundry\\Data Immersion\\Python Fundamentals for Data Analytics\\11-12-2024 Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_merged_derived.pkl'))

# %%
# check ords_prods_merge shape
ords_prods_merge.shape
# Out:
# (32251812, 18)

# %%
# create subset
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 18)

# %%
df.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
# 5   2398795        1             2                   3                  7
# 6   2398795        1             2                   3                  7
# 7   2398795        1             2                   3                  7
# 8   2398795        1             2                   3                  7
# 9   2398795        1             2                   3                  7
#
#    days_since_last_order  first_order  product_id  add_to_cart_order  \
# 0                    NaN         True         196                  1
# 1                    NaN         True       14084                  2
# 2                    NaN         True       12427                  3
# 3                    NaN         True       26088                  4
# 4                    NaN         True       26405                  5
# 5                   15.0        False         196                  1
# 6                   15.0        False       10258                  2
# 7                   15.0        False       12427                  3
# 8                   15.0        False       13176                  4
# 9                   15.0        False       26088                  5
#
#    reordered                             product_name  aisle_id  \
# 0          0                                     Soda        77
# 1          0  Organic Unsweetened Vanilla Almond Milk        91
# 2          0                      Original Beef Jerky        23
# 3          0               Aged White Cheddar Popcorn        23
# 4          0         XL Pick-A-Size Paper Towel Rolls        54
# 5          1                                     Soda        77
# 6          0                               Pistachios       117
# 7          1                      Original Beef Jerky        23
# 8          0                   Bag of Organic Bananas        24
# 9          1               Aged White Cheddar Popcorn        23
#
#    department_id  prices _merge     busiest_day   busiest days  \
# 0              7     9.0   both  Regularly busy  Regulary busy
# 1             16    12.5   both  Regularly busy  Regulary busy
# 2             19     4.4   both  Regularly busy  Regulary busy
# 3             19     4.7   both  Regularly busy  Regulary busy
# 4             17     1.0   both  Regularly busy  Regulary busy
# 5              7     9.0   both  Regularly busy   Slowest days
# 6             19     3.0   both  Regularly busy   Slowest days
# 7             19     4.4   both  Regularly busy   Slowest days
# 8              4    10.3   both  Regularly busy   Slowest days
# 9             19     4.7   both  Regularly busy   Slowest days
#
#   busiest_period_of_day
# 0        Average orders
# 1        Average orders
# 2        Average orders
# 3        Average orders
# 4        Average orders
# 5        Average orders
# 6        Average orders
# 7        Average orders
# 8        Average orders
# 9        Average orders

# %% [markdown]
# # 03. Grouping Data

# %%
# group df by 'product_name'
df.groupby('product_name')

# %% [markdown]
# # 04. Aggregating Data

# %%
# group 'deparment_id' and calculate mean value of order_number
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     14.800024
# 2     17.091743
# 3     17.913544
# 4     17.893092
# 5     15.214270
# 6     15.382135
# 7     17.694027
# 8     16.458105
# 9     15.957363
# 10    20.091818
# 11    16.482026
# 12    15.615061
# 13    16.484023
# 14    17.524632
# 15    15.691875
# 16    18.014071
# 17    16.150593
# 18    19.602850
# 19    17.631340
# 20    17.138607
# 21    21.956893
# Name: order_number, dtype: float64

# %%
# group 'department_id' and calculate mean, min, max values for 'order_number'
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.800024   1  99
# 2                17.091743   1  98
# 3                17.913544   1  99
# 4                17.893092   1  99
# 5                15.214270   1  99
# 6                15.382135   1  99
# 7                17.694027   1  99
# 8                16.458105   1  91
# 9                15.957363   1  99
# 10               20.091818   1  99
# 11               16.482026   1  99
# 12               15.615061   1  99
# 13               16.484023   1  99
# 14               17.524632   1  99
# 15               15.691875   1  99
# 16               18.014071   1  99
# 17               16.150593   1  99
# 18               19.602850   1  99
# 19               17.631340   1  99
# 20               17.138607   1  99
# 21               21.956893   1  97

# %%
# create 'max_order' column by grouping 'user_id' to determine amount of orders that each customer places
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\kthav\AppData\Local\Temp\ipykernel_13284\4153739739.py:2: FutureWarning: The provided callable <function max at 0x00000284CB114400> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
# 5   2398795        1             2                   3                  7
# 6   2398795        1             2                   3                  7
# 7   2398795        1             2                   3                  7
# 8   2398795        1             2                   3                  7
# 9   2398795        1             2                   3                  7
#
#    days_since_last_order  first_order  product_id  add_to_cart_order  \
# 0                    NaN         True         196                  1
# 1                    NaN         True       14084                  2
# 2                    NaN         True       12427                  3
# 3                    NaN         True       26088                  4
# 4                    NaN         True       26405                  5
# 5                   15.0        False         196                  1
# 6                   15.0        False       10258                  2
# 7                   15.0        False       12427                  3
# 8                   15.0        False       13176                  4
# 9                   15.0        False       26088                  5
#
#    reordered                             product_name  aisle_id  \
# 0          0                                     Soda        77
# 1          0  Organic Unsweetened Vanilla Almond Milk        91
# 2          0                      Original Beef Jerky        23
# 3          0               Aged White Cheddar Popcorn        23
# 4          0         XL Pick-A-Size Paper Towel Rolls        54
# 5          1                                     Soda        77
# 6          0                               Pistachios       117
# 7          1                      Original Beef Jerky        23
# 8          0                   Bag of Organic Bananas        24
# 9          1               Aged White Cheddar Popcorn        23
#
#    department_id  prices _merge     busiest_day   busiest days  \
# 0              7     9.0   both  Regularly busy  Regulary busy
# 1             16    12.5   both  Regularly busy  Regulary busy
# 2             19     4.4   both  Regularly busy  Regulary busy
# 3             19     4.7   both  Regularly busy  Regulary busy
# 4             17     1.0   both  Regularly busy  Regulary busy
# 5              7     9.0   both  Regularly busy   Slowest days
# 6             19     3.0   both  Regularly busy   Slowest days
# 7             19     4.4   both  Regularly busy   Slowest days
# 8              4    10.3   both  Regularly busy   Slowest days
# 9             19     4.7   both  Regularly busy   Slowest days
#
#   busiest_period_of_day  max_order
# 0        Average orders         10
# 1        Average orders         10
# 2        Average orders         10
# 3        Average orders         10
# 4        Average orders         10
# 5        Average orders         10
# 6        Average orders         10
# 7        Average orders         10
# 8        Average orders         10
# 9        Average orders         10

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# ..       ...      ...           ...                 ...                ...
# 95    738281        2             4                   2                 10
# 96   1673511        2             5                   3                 11
# 97   1673511        2             5                   3                 11
# 98   1673511        2             5                   3                 11
# 99   1673511        2             5                   3                 11
#
#     days_since_last_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
# ..                    ...          ...         ...                ...
# 95                    8.0        False       21150                 13
# 96                    8.0        False       47144                  1
# 97                    8.0        False        5322                  2
# 98                    8.0        False       17224                  3
# 99                    8.0        False       38656                  4
#
#     reordered                                       product_name  aisle_id  \
# 0           0                                               Soda        77
# 1           0            Organic Unsweetened Vanilla Almond Milk        91
# 2           0                                Original Beef Jerky        23
# 3           0                         Aged White Cheddar Popcorn        23
# 4           0                   XL Pick-A-Size Paper Towel Rolls        54
# ..        ...                                                ...       ...
# 95          0                            Fire Grilled Steak Bowl        38
# 96          0     Unsweetened Original Almond Breeze Almond Milk        91
# 97          0  Gluten Free Dark Chocolate Chunk Chewy with a ...         3
# 98          0                   Oats & Honey Gluten Free Granola         3
# 99          0  Gluten Free Peanut Butter Dark Chocolate Chewy...         3
#
#     department_id  prices _merge     busiest_day   busiest days  \
# 0               7     9.0   both  Regularly busy  Regulary busy
# 1              16    12.5   both  Regularly busy  Regulary busy
# 2              19     4.4   both  Regularly busy  Regulary busy
# 3              19     4.7   both  Regularly busy  Regulary busy
# 4              17     1.0   both  Regularly busy  Regulary busy
# ..            ...     ...    ...             ...            ...
# 95              1     5.9   both  Regularly busy  Regulary busy
# 96             16    14.0   both  Regularly busy   Slowest days
# 97             19     2.9   both  Regularly busy   Slowest days
# 98             19     1.6   both  Regularly busy   Slowest days
# 99             19     3.4   both  Regularly busy   Slowest days
#
#    busiest_period_of_day  max_order
# 0         Average orders         10
# 1         Average orders         10
# 2         Average orders         10
# 3         Average orders         10
# 4         Average orders         10
# ..                   ...        ...
# 95           Most orders         14
# 96           Most orders         14
# 97           Most orders         14
# 98           Most orders         14
# 99           Most orders         14
#
# [100 rows x 19 columns]

# %% [markdown]
# # Deriving Columns

# %%
# create column 'loyalty_flag' to flag loyal customers
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15800757
# Loyal customer      10237475
# New customer         6213580
# Name: count, dtype: int64

# %%
# check column for errors
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# 20        1      New customer             4
# 21        1      New customer             5
# 22        1      New customer             5
# 23        1      New customer             5
# 24        1      New customer             5
# 25        1      New customer             5
# 26        1      New customer             5
# 27        1      New customer             5
# 28        1      New customer             5
# 29        1      New customer             6
# 30        1      New customer             6
# 31        1      New customer             6
# 32        1      New customer             6
# 33        1      New customer             7
# 34        1      New customer             7
# 35        1      New customer             7
# 36        1      New customer             7
# 37        1      New customer             7
# 38        1      New customer             8
# 39        1      New customer             8
# 40        1      New customer             8
# 41        1      New customer             8
# 42        1      New customer             8
# 43        1      New customer             8
# 44        1      New customer             9
# 45        1      New customer             9
# 46        1      New customer             9
# 47        1      New customer             9
# 48        1      New customer             9
# 49        1      New customer             9
# 50        1      New customer            10
# 51        1      New customer            10
# 52        1      New customer            10
# 53        1      New customer            10
# 54        1      New customer            10
# 55        1      New customer            10
# 56        1      New customer            10
# 57        1      New customer            10
# 58        1      New customer            10
# 59        2  Regular customer             1
